# %%
# Series in pandas are arrays .

# importing and defining Series :

from pandas import Series
se = Series([1, 2, 3, 4, 5])
se                                  # displaying series se.
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
se[2]                       # getting a specific element using indicies.
# Out:
# 3

# %%
# defining indicies according to ourself :

se2 = Series([100, 200, 300], ['a', 'b', 'c'])
se2
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
se2['b']                      # getting a specific element using indicies.
# Out:
# 200
